# %% [markdown]
# >
# >
# >
# >
# ## by: <font color="#800080">Basma Abd-Elhalem </font>

# %% [markdown]
# ### Data Scaling
# For an algorithm, to perform at its best, the data should be on the same scale. When it comes to data scaling in python, we got two key techniques Standardization and Normalization.
# in this segment we will see how Standardization techniques can be applied to the data in our hands.
#
# ### What is data standardization?
# Data standardization is the process of converting data to a common format to enable users to process and analyze it. data from disparate sources can be problematic if it isn’t uniform, leading to difficulties down the line.
#
# Data standardization is crucial for many reasons. First of all, it helps you establish clear, consistently defined elements and attributes, providing a comprehensive catalog of your data. Whatever insights you’re trying to get or problems you’re attempting to solve, properly understanding your data is a crucial starting point.

# %%
### Operantions done on the data before scaling
1. first off the Target columb needs to be dropped for example: how it was done [here](#drop)
2. we need to filtter the data so that only the numeric value are left so that we can apply scaling for examplehow it was done [here](#numeric)

# %%
#DROP target column 
import pandas as pd
import os
import numpy as np 
import pandas as pd 
import warnings
import seaborn as sns
import matplotlib.pyplot as plt
dforg = pd.read_csv('heart.csv')
dforg.head(10)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
# 5   39   M           NAP        120          339          0     Normal    170
# 6   45   F           ATA        130          237          0     Normal    170
# 7   54   M           ATA        110          208          0     Normal    142
# 8   37   M           ASY        140          207          0     Normal    130
# 9   48   F           ATA        120          284          0     Normal    120
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# ...

# %%
numerical_col=dforg.select_dtypes(exclude = ['object'])
numerical_col.head(10)
# Out:
#    Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease
# 0   40        140          289          0    172      0.0             0
# 1   49        160          180          0    156      1.0             1
# 2   37        130          283          0     98      0.0             0
# 3   48        138          214          0    108      1.5             1
# 4   54        150          195          0    122      0.0             0
# 5   39        120          339          0    170      0.0             0
# 6   45        130          237          0    170      0.0             0
# 7   54        110          208          0    142      0.0             0
# 8   37        140          207          0    130      1.5             1
# 9   48        120          284          0    120      0.0             0

# %%
#important information for scaling
numerical_col.describe()
numerical_col.head(10)
# Out:
#    Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease
# 0   40        140          289          0    172      0.0             0
# 1   49        160          180          0    156      1.0             1
# 2   37        130          283          0     98      0.0             0
# 3   48        138          214          0    108      1.5             1
# 4   54        150          195          0    122      0.0             0
# 5   39        120          339          0    170      0.0             0
# 6   45        130          237          0    170      0.0             0
# 7   54        110          208          0    142      0.0             0
# 8   37        140          207          0    130      1.5             1
# 9   48        120          284          0    120      0.0             0

# %% [markdown]
# ## <font color="#800080"> Standralization the StandardScaler library </font>

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
trans2 = StandardScaler()
scaled_numerical_col = trans2.fit_transform(numerical_col)
scaled_numerical_col = pd.DataFrame(scaled_numerical_col)
scaled_numerical_col.head(10)
#scaled_numerical_col
# Out:
#           0         1         2         3         4         5         6
# 0 -1.433140  0.410909  0.825070 -0.551341  1.382928 -0.832432 -1.113115
# 1 -0.478484  1.491752 -0.171961 -0.551341  0.754157  0.105664  0.898380
# 2 -1.751359 -0.129513  0.770188 -0.551341 -1.525138 -0.832432 -1.113115
# 3 -0.584556  0.302825  0.139040 -0.551341 -1.132156  0.574711  0.898380
# 4  0.051881  0.951331 -0.034755 -0.551341 -0.581981 -0.832432 -1.113115
# 5 -1.539213 -0.669935  1.282424 -0.551341  1.304332 -0.832432 -1.113115
# 6 -0.902775 -0.129513  0.349422 -0.551341  1.304332 -0.832432 -1.113115
# 7  0.051881 -1.210356  0.084157 -0.551341  0.203982 -0.832432 -1.113115
# 8 -1.751359  0.410909  0.075010 -0.551341 -0.267596  0.574711  0.898380
# 9 -0.584556 -0.669935  0.779335 -0.551341 -0.660578 -0.832432 -1.113115

# %%
numerical_col.columns
# Out:
# Index(['Age', 'RestingBP', 'Cholesterol', 'FastingBS', 'MaxHR', 'Oldpeak',
#        'HeartDisease'],
#       dtype='object')

# %%
cols = ['Age', 'RestingBP', 'Cholesterol', 'FastingBS', 'MaxHR', 'Oldpeak',
       'HeartDisease']
 
#Call the sklearn librart and import scaler values 
from sklearn.preprocessing import StandardScaler
import seaborn as sns
 
#import matplotplib 
import matplotlib.pyplot as plt
 
#call the standard scaler 
std_scaler = StandardScaler()
 
#fit the values to the function 
Stand_Sc = std_scaler.fit_transform(numerical_col[cols].iloc[:,range(0,7)].values)
 
#use seaborn for KDE plot
sns.kdeplot(Stand_Sc[:,5],fill=True, color = 'Green')
 
#Label the plot 
plt.xlabel('standardized values ')
 
#Print the plot 
plt.show()
